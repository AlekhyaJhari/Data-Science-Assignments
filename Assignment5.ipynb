# %%
# Assignment 5: Exploratory Data Analysis (EDA) on Cardiographic Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.listdir())
# Out:
# ['1b6a188127', '8a7abeba6e', 'bin', 'Code.exe', 'Code.VisualElementsManifest.xml', 'is-TAH5M.tmp', 'unins000.dat', 'unins000.exe', 'unins000.msg']

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\hp\AppData\Local\Programs\Microsoft VS Code

# %%
import os
os.chdir(r"C:\Users\hp")
print(os.getcwd())
