# %% [markdown]
# # Assignment 3: Basic Statistics
# ### Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0           1        138      73           11         276    120       Bad
# 1           2        111      48           16         260     83      Good
# 2           3        113      35           10         269     80    Medium
# 3           4        117     100            4         466     97    Medium
# 4           5        141      64            3         340    128       Bad
#
#    Age  Education Urban   US high
# 0   42         17   Yes  Yes  yes
# 1   65         10   Yes  Yes  yes
# 2   59         12   Yes  Yes  yes
# 3   55         14   Yes  Yes   no
# 4   38         13   Yes   No   no

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   400 non-null    int64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    str
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    str
#  10  US           400 non-null    str
#  11  high         400 non-null    str
# dtypes: int64(8), str(4)
# memory usage: 37.6 KB

# %%
df.describe()
# Out:
#        Unnamed: 0   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean   200.500000  124.975000   68.657500     6.635000  264.840000
# std    115.614301   15.334512   27.986037     6.650364  147.376436
# min      1.000000   77.000000   21.000000     0.000000   10.000000
# 25%    100.750000  115.000000   42.750000     0.000000  139.000000
# 50%    200.500000  125.000000   69.000000     5.000000  272.000000
# 75%    300.250000  135.000000   91.000000    12.000000  398.500000
# max    400.000000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %% [markdown]
# # Calculate Mean,Median,Mode & Standard Deviation

# %%
print("Mean")
print(df.mean(numeric_only=True))
print("\nMedian")
print(df.median(numeric_only=True))
print("\nMode")
print(df.mode())
print("\nStandard Deviation")
print(df.std(numeric_only=True))
# Out:
# Mean
# Unnamed: 0     200.5000
# CompPrice      124.9750
# Income          68.6575
# Advertising      6.6350
# Population     264.8400
# Price          115.7950
# Age             53.3225
# Education       13.9000
# dtype: float64
#
# Median
# Unnamed: 0     200.5
# CompPrice      125.0
# Income          69.0
# Advertising      5.0
# Population     272.0
# Price          117.0
# Age             54.5
# Education       14.0
# dtype: float64
#
# Mode
#      Unnamed: 0  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0             1      121.0    69.0          0.0       125.0  120.0    Medium
# 1             2        NaN     NaN          NaN       148.0  128.0       NaN
# 2             3        NaN     NaN          NaN       170.0    NaN       NaN
# 3             4        NaN     NaN          NaN       220.0    NaN       NaN
# 4             5        NaN     NaN          NaN       237.0    NaN       NaN
# ...

# %%
df.hist(figsize=(12,10))
plt.show()

# %%
df.boxplot(figsize=(12,8))
plt.show()

# %% [markdown]
# # Histograms

# %%
df.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar Chart Analysis for Categorical Columns

# %%
categorical_columns = ["ShelveLoc", "Urban", "US", "high"]
for col in categorical_columns:
    plt.figure(figsize=(5,4))
    df[col].value_counts().plot(kind="bar")
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ## Conclusion
#
# • The dataset contains 400 records with both numerical and categorical variables.
# • Descriptive statistics helped understand the central tendency and spread of numerical columns.
# • Histograms showed the distribution of numerical variables.
# • Boxplots helped identify the spread and possible outliers.
# • Bar charts displayed the frequency distribution of categorical variables.
# • Overall, the dataset is ready for further preprocessing and predictive analysis.
